# %%
# %load_ext autoreload
# %autoreload 2

import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
from darts import TimeSeries
from darts.utils.data import tabularization as tab
from mlxtend.feature_selection import SequentialFeatureSelector
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from darts.metrics import mape, r2_score, rmse
from darts.models import RegressionModel

import utils

warnings.filterwarnings('ignore')

# %%
# Load data
df = utils.load_data()

# Convert the dataframe to multiple TimeSeries objects (one per pre-processing method)
ts, covars_diff, covars_diff_yoy, covars_nodiff = utils.df2ts(df)

# Scale the time series and covariates
covars_diff_pipeline, covars_diff_scaled = utils.scale_ts(
    covars_diff, should_diff=True, diff_order=1, should_scale=False, should_log=True
)
covars_nodiff_pipeline, covars_nodiff_scaled = utils.scale_ts(
    covars_nodiff, should_diff=False, should_scale=False, should_log=True
)
covars_diff_yoy_pipeline, covars_diff_yoy_scaled = utils.scale_ts(
    covars_diff_yoy, should_diff=True, diff_order=12, should_scale=False, should_log=True
)
pipeline, ts_scaled = utils.scale_ts(ts, should_diff=True, diff_order=1, should_scale=False, should_log=True)


# Ensure that all timeseries are aligned (i.e. have the same time range). This is required for stacking them together.
covars_diff_scaled = covars_diff_scaled.slice_intersect(covars_diff_yoy_scaled)
covars_nodiff_scaled = covars_nodiff_scaled.slice_intersect(covars_diff_yoy_scaled)

# Stack the covariates
covariates_scaled = covars_diff_scaled.stack(covars_nodiff_scaled).stack(
    covars_diff_yoy_scaled
)


# Split the data into training and validation sets
train_ts, val_ts = ts.split_after(pd.Timestamp("2016-01-01"))
train_ts_scaled, val_ts_scaled = ts_scaled.split_after(pd.Timestamp("2016-01-01"))
train_covariates_scaled, val_covariates_scaled = covariates_scaled.split_after(
    pd.Timestamp("2016-01-01")
)

# Reconvert to DataFrame since statsmodels does not support TimeSeries objects
train = train_ts_scaled.pd_dataframe()
validation = val_ts_scaled.pd_dataframe()
history = pd.concat([train, validation])

# %%
timeseries_crossval = TimeSeriesSplit(n_splits=10)

# %%
lags_past_covariates = {
        "US_UNEMPLOYMENT_RATE": [-3],
        "US_CPI": [-3],
        "US_TB_YIELD_3YRS": [-2],
        "YIELD_CURVE": [-1],
        "EXPINF10YR": [-1],
        "MICH": [-1],
        "US_TB_YIELD_5YRS": [-1],
        "NEWS_SENTIMENT": [-2],
    }

unwanted_columns = [c for c in train_covariates_scaled.columns if c not in lags_past_covariates.keys()]
train_covariates_scaled = train_covariates_scaled.drop_columns(unwanted_columns)
covariates_scaled = covariates_scaled.drop_columns(unwanted_columns)


model = linear_model.LassoCV(cv=timeseries_crossval)
ts_model = RegressionModel(
    model=model,
    lags=[-5, -10],
    lags_past_covariates=lags_past_covariates,
    output_chunk_length=36,
)

ts_model.fit(
    series=train_ts_scaled,
    past_covariates=train_covariates_scaled,
)
# Out:
# RegressionModel(lags=[-5, -10], lags_past_covariates={'US_UNEMPLOYMENT_RATE': [-3], 'US_CPI': [-3], 'US_TB_YIELD_3YRS': [-2], 'YIELD_CURVE': [-1], 'EXPINF10YR': [-1], 'MICH': [-1], 'US_TB_YIELD_5YRS': [-1], 'NEWS_SENTIMENT': [-2]}, lags_future_covariates=None, output_chunk_length=36, output_chunk_shift=0, add_encoders=None, model=LassoCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None)), multi_models=True, use_static_covariates=True)

# %%
forecasts = utils.make_forecasts(ts_model, ts, ts_scaled, covariates_scaled, pipeline)

# %%
utils.evaluate_by_horizon(forecasts)
# Out:
# component  mean_abs_pct_error  mean_squared_error  mean_abs_error  \
# horizon
# 1                    7.397707            0.037425        0.145405
# 2                   12.281193            0.102034        0.239236
# 3                   16.185296            0.172535        0.308020
# 4                   19.977477            0.245974        0.377463
# 5                   23.385870            0.327408        0.445490
# 6                   26.599666            0.426646        0.513045
# 7                   29.967680            0.536099        0.580303
# 8                   33.077047            0.644540        0.644237
# 9                   35.764442            0.753486        0.700722
# 10                  38.439176            0.867989        0.757985
# 11                  40.902303            0.991097        0.813678
# 12                  43.202401            1.108860        0.859465
# 13                  45.480823            1.212932        0.903256
# 14                  47.166410            1.325690        0.934934
# 15                  48.903381            1.459383        0.970982
# 16                  50.775464            1.600686        1.007283
# 17                  52.565518            1.747121        1.040511
# 18                  54.091625            1.872992        1.069468
# 19                  55.702660            2.031560        1.113341
# 20                  56.570229            2.140767        1.134266
# 21                  57.417501            2.244832        1.154829
# 22                  57.842045            2.346100        1.169708
# 23                  58.030815            2.450920        1.184054
# 24                  58.557519            2.540939        1.205913
# 25                  59.039976            2.619519        1.227738
# 26                  59.523578            2.682096        1.249060
# 27                  59.807727            2.738711        1.270467
# 28                  59.651545            2.794041        1.286831
# 29                  59.435094            2.862163        1.304509
# 30                  58.574125            2.924491        1.310787
# 31                  57.458650            2.944033        1.308349
# 32                  56.825059            2.932851        1.308916
# 33                  55.970261            2.900770        1.303427
# 34                  55.140583            2.857648        1.295988
# 35                  54.038421            2.803226        1.282186
# 36                  53.521232            2.736582        1.272602
#
# component  root_mean_squared_error
# horizon
# 1                         0.193454
# 2                         0.319427
# 3                         0.415373
# 4                         0.495958
# 5                         0.572196
# 6                         0.653181
# 7                         0.732188
# 8                         0.802832
# 9                         0.868036
# 10                        0.931659
# 11                        0.995538
# 12                        1.053024
# 13                        1.101332
# 14                        1.151386
# 15                        1.208049
# 16                        1.265182
# 17                        1.321787
# 18                        1.368573
# 19                        1.425328
# 20                        1.463136
# 21                        1.498276
# 22                        1.531698
# 23                        1.565541
# 24                        1.594032
# 25                        1.618493
# 26                        1.637711
# 27                        1.654905
# 28                        1.671538
# 29                        1.691793
# 30                        1.710114
# 31                        1.715819
# 32                        1.712557
# 33                        1.703165
# 34                        1.690458
# 35                        1.674284
# 36                        1.654262

# %%
fore_ts = utils.get_ts_by_forecast_horizon(forecasts)

# %%
utils.plot_forecast_for_horizon(
    1, fore_ts, axs=plt.subplots(1, 1, figsize=(10, 6))[1], ts=ts
)

# %%
from darts.models import XGBModel


model = XGBModel(
    # max_depth=5,
    # n_estimators=100,
    # n_jobs=10,
    lags=[-5, -10],
    lags_past_covariates=lags_past_covariates,
    output_chunk_length=36,
    verbose=True,
    likelihood="quantile"
)

model.fit(train_ts_scaled, train_covariates_scaled)
# Out:
# XGBModel(lags=[-5, -10], lags_past_covariates={'US_UNEMPLOYMENT_RATE': [-3], 'US_CPI': [-3], 'US_TB_YIELD_3YRS': [-2], 'YIELD_CURVE': [-1], 'EXPINF10YR': [-1], 'MICH': [-1], 'US_TB_YIELD_5YRS': [-1], 'NEWS_SENTIMENT': [-2]}, lags_future_covariates=None, output_chunk_length=36, output_chunk_shift=0, add_encoders=None, likelihood=quantile, quantiles=None, random_state=None, multi_models=True, use_static_covariates=True, verbose=True)

# %%
forecasts = utils.make_forecasts(model, ts, ts_scaled, covariates_scaled, pipeline)

# %%
utils.evaluate_by_horizon(forecasts)
# Out:
# component  mean_abs_pct_error  mean_squared_error  mean_abs_error  \
# horizon
# 1                    7.932487            0.040481        0.158230
# 2                   14.242493            0.131157        0.281049
# 3                   18.115849            0.179183        0.336322
# 4                   22.526322            0.261492        0.413968
# 5                   27.148007            0.361979        0.491652
# 6                   30.794098            0.496413        0.563944
# 7                   33.536162            0.616804        0.627561
# 8                   35.185849            0.697898        0.666062
# 9                   38.505671            0.826977        0.722495
# 10                  41.800882            1.015891        0.784130
# 11                  44.297617            1.147350        0.823016
# 12                  45.511745            1.247749        0.843549
# 13                  45.387299            1.317427        0.854429
# 14                  46.915816            1.370111        0.884034
# 15                  47.639090            1.461919        0.900574
# 16                  47.394994            1.467704        0.886931
# 17                  48.538846            1.503057        0.894483
# 18                  49.039814            1.524303        0.900818
# 19                  49.490811            1.544051        0.910665
# 20                  49.702464            1.584710        0.916135
# 21                  49.142885            1.482411        0.896795
# 22                  48.512216            1.428594        0.902524
# 23                  48.501892            1.442031        0.914013
# 24                  49.141928            1.473131        0.932135
# 25                  49.487577            1.593434        0.966986
# 26                  48.893857            1.619752        0.966401
# 27                  48.519347            1.654484        0.977677
# 28                  49.216362            1.764153        1.014930
# 29                  49.070230            1.867850        1.036858
# 30                  47.677254            1.885713        1.033417
# 31                  47.141376            1.972917        1.054248
# 32                  45.527949            2.012430        1.045833
# 33                  44.667039            2.022433        1.048651
# 34                  45.080638            2.063705        1.055647
# 35                  45.023425            2.024745        1.040550
# 36                  43.419084            1.963549        1.007711
#
# component  root_mean_squared_error
# horizon
# 1                         0.201200
# 2                         0.362156
# 3                         0.423301
# 4                         0.511363
# 5                         0.601647
# 6                         0.704566
# 7                         0.785368
# 8                         0.835403
# 9                         0.909383
# 10                        1.007914
# 11                        1.071144
# 12                        1.117027
# 13                        1.147792
# 14                        1.170517
# 15                        1.209098
# 16                        1.211488
# 17                        1.225992
# 18                        1.234626
# 19                        1.242599
# 20                        1.258853
# 21                        1.217543
# 22                        1.195238
# 23                        1.200846
# 24                        1.213726
# 25                        1.262313
# 26                        1.272695
# 27                        1.286267
# 28                        1.328214
# 29                        1.366693
# 30                        1.373213
# 31                        1.404606
# 32                        1.418602
# 33                        1.422123
# 34                        1.436560
# 35                        1.422935
# 36                        1.401267

# %%
ts_forecasts = utils.get_ts_by_forecast_horizon(forecasts)

# %%
utils.plot_forecast_for_horizon(
    1, ts_forecasts, axs=plt.subplots(1, 1, figsize=(10, 6))[1], ts=ts
)
